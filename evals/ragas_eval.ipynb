# %% [markdown]
# # RAGAS Evaluation Notebook
#
# Compare baseline embeddings (`all-MiniLM-L6-v2`) vs improved model (`jinaai/jina-embeddings-v2-base-de`).

# %%
import pandas as pd
from datasets import Dataset

qa_df = pd.read_csv('qa_pairs.csv')
qa_df.head()

# %% [markdown]
# ## TODO: Build two pipelines
# - Baseline: `sentence-transformers/all-MiniLM-L6-v2`
# - Improved: `jinaai/jina-embeddings-v2-base-de`

# %%
# TODO: generate answers for each model and create evaluation dataset
eval_dataset = Dataset.from_pandas(qa_df)
eval_dataset

# %%
# TODO: run ragas metrics (faithfulness, answer_relevancy, context_precision, context_recall)
# from ragas import evaluate
# from ragas.metrics import faithfulness, answer_relevancy, context_precision, context_recall
